# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Step 1: 
data = {
    "x1": [1,2,3,8,9,10,25,26,27],
    "x2": [2,3,4,9,10,11,26,27,28]
}

df = pd.DataFrame(data)

# Step 2: Model
model = KMeans(n_clusters=3)

# Step 3: Train + Predict
df["Cluster"] = model.fit_predict(df)

# Step 4: Output
print(df)

# Step 5: Graph
plt.scatter(df["x1"], df["x2"], c=df["Cluster"])
plt.title("K-Means Clustering")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()
# Out:
# /lib/python3.13/site-packages/threadpoolctl.py:1123: RuntimeWarning: JsProxy.as_object_map() is deprecated. Use as_py_json() instead.
#   for filepath in LDSO.loadedLibsByName.as_object_map():
#    x1  x2  Cluster
# 0   1   2        2
# 1   2   3        2
# 2   3   4        2
# 3   8   9        1
# 4   9  10        1
# 5  10  11        1
# 6  25  26        0
# 7  26  27        0
# 8  27  28        0
